# %% [raw]
# ---
# description: The main module for machine learning and deep learning library
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()
